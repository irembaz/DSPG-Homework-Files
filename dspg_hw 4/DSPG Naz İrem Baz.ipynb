# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/irem/Desktop/NAZ_İREM BAZ_WEEK_6/googleplaystore.csv", engine='python')

# %%
df.head(100)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite â€“ FREE Live Cool Themes, Hid...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df["Installs"].replace({"0+":0,"1+":1,"5+":5,"10+":10,"50+":50,"100+":100,"500+":500
                    ,"1,000+":1000,"5,000+":5000,"10,000+":10000,"50,000+":50000,"100,000+":100000,
                        "500,000+":500000,"1,000,000+":1000000,"5,000,000+":5000000,
                        "10,000,000+":10000000,"50,000,000+":50000000,"100,000,000+":100000000,
                        "500,000,000+":500000000,"1,000,000,000+":1000000000,"0":0,"Free":0},inplace=True)

# %%
#convert_dict = {'Installs': int, 
#df = df.astype(convert_dict) 
#print(df.dtypes) BU NEDEN HATA VERİYOR ÇÖZEMEDİM                     } 
df['Installs'] = df['Installs'].astype(str).astype(int)

print(df["Installs"])
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
# 5           50000
# 6           50000
# 7         1000000
# 8         1000000
# 9           10000
# 10        1000000
# 11        1000000
# 12       10000000
# 13         100000
# 14         100000
# 15           5000
# 16         500000
# 17          10000
# 18        5000000
# 19       10000000
# 20         100000
# 21         100000
# 22         500000
# 23         100000
# 24          50000
# 25          10000
# 26         500000
# 27         100000
# 28          10000
# 29         100000
#            ...
# 10811         100
# 10812        1000
# 10813       10000
# 10814       50000
# 10815      500000
# 10816         100
# 10817      100000
# 10818       10000
# 10819        5000
# 10820        1000
# 10821          50
# 10822          10
# 10823         100
# 10824       10000
# 10825         100
# 10826     5000000
# 10827        5000
# 10828       10000
# 10829       10000
# ...

# %%
df.info("Installs")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null int32
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1.0+ MB

# %%
df["Installs"].mean()
df["Installs"].median()
# Out:
# 100000.0

# %%
filt=(df["Installs"]>100000) & (df["Type"]=="Free")
df.loc[filt]
# Out:
#                                                      App             Category  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...

# %%
df.describe()
# Out:
#             Rating      Installs
# count  9367.000000  1.084100e+04
# mean      4.193338  1.546291e+07
# std       0.537431  8.502557e+07
# min       1.000000  0.000000e+00
# 25%       4.000000  1.000000e+03
# 50%       4.300000  1.000000e+05
# 75%       4.500000  5.000000e+06
# max      19.000000  1.000000e+09

# %%
df["Installs"].value_counts()
# Out:
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               16
# Name: Installs, dtype: int64

# %%
grouped=df.groupby(["Category"])
grouped["Genres"].value_counts()
# Out:
# Category             Genres
# 1.9                  February 11, 2018                          1
# ART_AND_DESIGN       Art & Design                              58
#                      Art & Design;Creativity                    5
#                      Art & Design;Action & Adventure            1
#                      Art & Design;Pretend Play                  1
# AUTO_AND_VEHICLES    Auto & Vehicles                           85
# BEAUTY               Beauty                                    53
# BOOKS_AND_REFERENCE  Books & Reference                        231
# BUSINESS             Business                                 460
# COMICS               Comics                                    59
#                      Comics;Creativity                          1
# COMMUNICATION        Communication                            387
# DATING               Dating                                   234
# EDUCATION            Education                                129
# ...

# %%
#Missing Value Handling

# %%
df.dropna(axis="index",how="any")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
df.shape
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
df["Installs"].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0],
#       dtype=int64)

# %%
#sanırım tarih string olarak kaydedilmiş
#df["Last Updated"] = pd.to_datetime(df["Last Updated"], format="%Y-%m-%d")

# %%
### PLOTTING ###

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import math

# %matplotlib qt

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b666bf274d0a> in <module>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
plt.scatter(np.log10(df["Installs"]),df["Price"],color="b")
plt.scatter(np.log10(df["Installs"]),df["Reviews"],color="K")
plt.title("Relation btw Price and Installation")
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-38a184c63999> in <module>()
# ----> 1 plt.scatter(np.log10(df["Installs"]),df["Price"],color="b")
#       2 plt.scatter(np.log10(df["Installs"]),df["Reviews"],color="K")
#       3 plt.title("Relation btw Price and Installation")
#       4 #plt.show()
#
# NameError: name 'plt' is not defined
